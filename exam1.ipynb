# %%
import pandas as pd
score = pd.Series([95,90,85,90,95])
score
# Out:
# 0    95
# 1    90
# 2    85
# 3    90
# 4    95
# dtype: int64

# %%
df = pd.read_csv('player1.csv')
df
# Out:
#                       name  Age Overall rating Potential    Team & Contract  \
# 0         A. Younes LM CAM   29             73        73         Al Ettifaq
# 1      R. Sessegnon LB LWB   23             75        80  Tottenham Hotspur
# 2      Mikel Merino CM CAM   27             84        85      Real Sociedad
# 3          M. Prati CDM CM   19             73        85           Cagliari
# 4    L. Rodríguez RW LW ST   19             71        83          Liverpool
# ..                     ...  ...            ...       ...                ...
# 494        Éder Militão CB   25             86        89        Real Madrid
# 495           M. Gabbia CB   23             75        82              Milan
# 496         C. Kelleher GK   24             76        80          Liverpool
# 497       S. Tonali CDM CM   23             86        89   Newcastle United
# 498           M. Taremi ST   30             81        81              Porto
#
#          ID         Height         Weight   foot  Best overall  ...  \
# 0    205966   170cm / 5'7"  71kg / 157lbs  Right            73  ...
# 1    235883  178cm / 5'10"  70kg / 154lbs   Left            77  ...
# 2    225193   189cm / 6'2"  83kg / 183lbs   Left            85  ...
# 3    272725   185cm / 6'1"  75kg / 165lbs  Right            75  ...
# 4    273604  179cm / 5'10"  71kg / 157lbs  Right            72  ...
# ..      ...            ...            ...    ...           ...  ...
# 494  240130   186cm / 6'1"  78kg / 172lbs  Right            88  ...
# 495  240277   185cm / 6'1"  78kg / 172lbs  Right            77  ...
# 496  240913   188cm / 6'2"  81kg / 179lbs  Right            76  ...
# 497  241096  181cm / 5'11"  79kg / 174lbs  Right            87  ...
# 498  241788   185cm / 6'1"  83kg / 183lbs  Right            81  ...
#
#     GK Positioning  GK Reflexes Total stats Base stats  \
# 0               15           15        1842        387
# 1                8            7        1960        425
# 2               13           14        2282        480
# 3                6            9        1977        414
# 4               13           15        1879        400
# ..             ...          ...         ...        ...
# 494             12           15        2051        443
# 495             14           14        1651        351
# 496             75           78        1235        421
# 497              7            7        2279        485
# 498             15            8        1985        426
#
#     International reputation  Pace / Diving Shooting / Handling  \
# 0                          1             71                  67
# 1                          1             78                  64
# 2                          2             72                  79
# 3                          1             65                  65
# 4                          1             83                  74
# ..                       ...            ...                 ...
# 494                        3             85                  50
# 495                        1             53                  35
# 496                        1             75                  73
# 497                        3             84                  74
# 498                        2             78                  81
#
#     Passing / Kicking Dribbling / Reflexes Defending / Pace
# 0                  70                   79               38
# 1                  72                   76               71
# 2                  82                   82               83
# 3                  73                   72               69
# 4                  58                   77               37
# ..                ...                  ...              ...
# 494                69                   71               86
# 495                52                   58               77
# 496                77                   78               43
# 497                81                   81               82
# 498                75                   81               38
#
# [499 rows x 64 columns]

# %%
df.sort_values(by=['Best overall'], ascending=[False])
# Out:
#                     name  Age Overall rating Potential      Team & Contract  \
# 45         E. Haaland ST   22             91        94      Manchester City
# 13       K. Mbappé ST LW   24             91        94  Paris Saint Germain
# 422  K. De Bruyne CM CAM   32             91        91      Manchester City
# 79       L. Messi CF CAM   36             90        90          Inter Miami
# 80    P. Foden RW LW CAM   23             87        90      Manchester City
# ..                   ...  ...            ...       ...                  ...
# 333          S. Bamba LM   19             64    Feb.78    Borussia Dortmund
# 152        M. Faye CB LB   18             63        79         FC Barcelona
# 299       L. Vušković CB   16             62        86       Radomiak Radom
# 418    M. Sonko LW RW ST   18             63        84                 Gent
# 358       L. Vušković CB   16             62        86       Radomiak Radom
#
#          ID         Height         Weight   foot  Best overall  ...  \
# 45   239085   195cm / 6'5"  94kg / 207lbs   Left            93  ...
# 13   231747   182cm / 6'0"  75kg / 165lbs  Right            93  ...
# 422  192985  181cm / 5'11"  75kg / 165lbs  Right            91  ...
# 79   158023   169cm / 5'7"  67kg / 148lbs   Left            91  ...
# 80   237692   171cm / 5'7"  69kg / 152lbs   Left            90  ...
# ..      ...            ...            ...    ...           ...  ...
# 333  264543  179cm / 5'10"  70kg / 154lbs  Right            65  ...
# 152  277118   186cm / 6'1"  81kg / 179lbs   Left            65  ...
# 299  275192   193cm / 6'4"  86kg / 190lbs  Right            64  ...
# 418  271953   176cm / 5'9"  65kg / 143lbs  Right            64  ...
# 358  275192   193cm / 6'4"  86kg / 190lbs  Right            64  ...
#
#     GK Positioning  GK Reflexes Total stats Base stats  \
# 45              11            7        2170        464
# 13              11            6        2204        473
# 422             10           13        2325        486
# 79              14            8        2166        448
# 80              10           13        2146        456
# ..             ...          ...         ...        ...
# 333              5           15        1476        324
# 152              9            7        1635        353
# 299             13           12        1634        362
# 418              8           10        1516        328
# 358             13           12        1634        362
#
#     International reputation  Pace / Diving Shooting / Handling  \
# 45                         5             89                  93
# 13                         5             97                  90
# 422                        5             74                  88
# 79                         5             80                  87
# 80                         3             83                  82
# ..                       ...            ...                 ...
# 333                        1             81                  50
# 152                        1             75                  41
# 299                        1             61                  61
# 418                        1             80                  61
# 358                        1             61                  61
#
#     Passing / Kicking Dribbling / Reflexes Defending / Pace
# 45                 68                   81               45
# 13                 80                   92               36
# 422                94                   87               65
# 79                 90                   94               33
# 80                 84                   90               57
# ..                ...                  ...              ...
# 333                57                   69               24
# 152                51                   54               59
# 299                50                   57               58
# 418                50                   69               17
# 358                50                   57               58
#
# [499 rows x 64 columns]

# %%
import numpy as np

# Wage 열에서 숫자로 변환하는 함수 정의
def parse_wage(value):
    if isinstance(value, str) and 'K' in value:
        return float(value.replace('€', '').replace('K', '')) * 1_000
    elif isinstance(value, str) and 'M' in value:
        return float(value.replace('€', '').replace('M', '')) * 1_000_000
    else:
        return np.nan

# Wage 열 숫자 변환
df['Wage (Numeric)'] = df['Wage'].apply(parse_wage)

# Overall rating 숫자 변환
df['Overall rating'] = pd.to_numeric(df['Overall rating'], errors='coerce')

# 두 변수 간 상관계수 계산
correlation = df[['Overall rating', 'Wage (Numeric)']].corr()

# 결과 출력
print("Overall rating과 연봉 간의 상관계수:")
print(correlation)
# Out:
# Overall rating과 연봉 간의 상관계수:
#                 Overall rating  Wage (Numeric)
# Overall rating        1.000000        0.719959
# Wage (Numeric)        0.719959        1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 산점도를 통한 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Overall rating', y='Wage (Numeric)', color='blue', alpha=0.7)

# 그래프 제목 및 축 레이블 추가
plt.title('Overall Rating vs. Wage', fontsize=16)
plt.xlabel('Overall Rating', fontsize=14)
plt.ylabel('Wage (in Euros)', fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)

# 그래프 표시
plt.show()
