# %%
import pandas as pd
score = pd.Series([95,90,85,90,95])
score
# Out:
# 0    95
# 1    90
# 2    85
# 3    90
# 4    95
# dtype: int64

# %%
df = pd.DataFrame({'name':['장은실','오경선','양숙희'],'score':[90,88,85],'dept':['com','eng','math']})
df
# Out:
#   name  score  dept
# 0  장은실     90   com
# 1  오경선     88   eng
# 2  양숙희     85  math

# %%
df = pd.read_csv('angel.csv')
df
# Out:
#                     name   Age Overall rating Potential    Team & Contract  \
# 0       A. Younes LM CAM  29.0             73        73         Al Ettifaq
# 1                    NaN   NaN            NaN       NaN        2022 ~ 2024
# 2    R. Sessegnon LB LWB  23.0             75        80  Tottenham Hotspur
# 3                    NaN   NaN            NaN       NaN        2019 ~ 2025
# 4    Mikel Merino CM CAM  27.0             84        85      Real Sociedad
# ..                   ...   ...            ...       ...                ...
# 993                  NaN   NaN            NaN       NaN        2017 ~ 2026
# 994     S. Tonali CDM CM  23.0             86        89   Newcastle United
# 995                  NaN   NaN            NaN       NaN        2023 ~ 2028
# 996         M. Taremi ST  30.0             81        81              Porto
# 997                  NaN   NaN            NaN       NaN        2020 ~ 2024
#
# ...

# %%
df.sort_values(by='Age')
# Out:
#                name   Age Overall rating Potential Team & Contract        ID  \
# 176  Pau Cubarsí CB  16.0             66        85    FC Barcelona  278046.0
# 958    L. Miller CM  16.0           64+1      84+1      Motherwell  275522.0
# 716  L. Vušković CB  16.0             62        86  Radomiak Radom  275192.0
# 598  L. Vušković CB  16.0             62        86  Radomiak Radom  275192.0
# 44    J. Hato CB LB  17.0             73        88            Ajax  272978.0
# ..              ...   ...            ...       ...             ...       ...
# 989             NaN   NaN            NaN       NaN     2019 ~ 2028       NaN
# 991             NaN   NaN            NaN       NaN     2017 ~ 2026       NaN
# 993             NaN   NaN            NaN       NaN     2017 ~ 2026       NaN
# 995             NaN   NaN            NaN       NaN     2023 ~ 2028       NaN
# 997             NaN   NaN            NaN       NaN     2020 ~ 2024       NaN
#
# ...
